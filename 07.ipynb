# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\nhatm\pycharmprojects\computervision\venv\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\nhatm\pycharmprojects\computervision\venv\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\nhatm\pycharmprojects\computervision\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nhatm\pycharmprojects\computervision\venv\lib\site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\nhatm\pycharmprojects\computervision\venv\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\nhatm\pycharmprojects\computervision\venv\lib\site-packages (from matplotlib) (2.1.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\nhatm\pycharmprojects\computervision\venv\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\nhatm\pycharmprojects\computervision\venv\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\nhatm\pycharmprojects\computervision\venv\lib\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nhatm\pycharmprojects\computervision\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\nhatm\pycharmprojects\computervision\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpl
from PIL import Image

# %%
my_path = 'C:/Users/nhatm/PycharmProjects/ComputerVision/img/logo.png'
im = Image.open(my_path)
plt.imshow(im)

# %%
x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 35]
plt.plot(x, y)
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 35]
plt.plot(x, y, color='red')
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 35]
plt.plot(x, y, color='green')
plt.title('Biểu đồ')
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 35]
plt.plot(x, y, color='green')
plt.title('Biểu đồ')
plt.axis('off')
plt.show()

# %%
im = Image.open(my_path)
x = [50, 75, 95, 120]
y = [100, 150, 175, 300]
plt.imshow(im)
plt.plot(x, y, 'bo--')
plt.show()
